# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.linalg import fractional_matrix_power

# %%
K = 60
n_x = 4
n_y_1 = 2
n_y_2 = 1

A_1 = np.array([[1, 0, 0.2, 0], [0, 1, 0, 0.2], [-0.2, 0, 0.8, 0], [0, 0, 0, 0.8]])
b_1 = np.array([[0], [0], [0.2], [0.2]])
x_initial_1 = np.array([[1], [1], [-15], [3]])

A_2 = np.array([[1, 0, 0.2, 0], [0, 1, 0, 0.2], [-0.1, 0, 0.8, 0], [0, 0, 0, 0.8]])
b_2 = np.array([[0], [0], [0.2], [0.2]])
x_initial_2 = np.array([[-2], [1], [-3], [3]])

P = np.array([[1, 0, 0, 0], [0, 1, 0, 0]])

# %%
def f_1(k, x_1_0):
    return np.linalg.matrix_power(A_1, k) @ x_1_0 + np.sum([np.linalg.matrix_power(A_1, n) @ b_1 for n in range(k)], axis=0)

def f_2(k, x_2_0):
    return np.linalg.matrix_power(A_2, k) @ x_2_0 + np.sum([np.linalg.matrix_power(A_2, n) @ b_2 for n in range(k)], axis=0)

def h_1(k, x_1_0):
    return P @ f_1(k, x_1_0)

def h_2(k, x_1_0, x_2_0):
    return np.linalg.norm(P @ f_2(k, x_2_0) - P @ f_1(k, x_1_0))

# %%
X_true = np.zeros((n_x + n_x, 1, K))
for k in range(K):
    X_true[:, :, k] = np.vstack((f_1(k, x_initial_1), f_2(k, x_initial_2)))

r_1 = 1e-2
R_1 = r_1**2 * np.eye(n_y_1)
sigma_2 = 1e-1
Y = np.zeros((n_y_1 + n_y_2, 1, K))
for k in range(K):
    Y[:n_y_1, :, k] = h_1(k, x_initial_1) + np.sqrt(R_1) @ np.random.randn(n_y_1, 1)
    Y[n_y_1:n_y_1 + n_y_2, :, k] = h_2(k, x_initial_1, x_initial_2) + sigma_2 * np.random.randn(n_y_2, 1)

# %%
plt.plot(X_true[0, 0, :], X_true[1, 0, :], '.-', label='Agent 1')
plt.plot(X_true[4, 0, :], X_true[5, 0, :], '.-', label='Agent 2')
plt.plot(Y[0, 0, :], Y[1, 0, :], '.', label='Measurement 1')
for k in range(K):
    x1 = X_true[0:2, 0, k]
    x2 = X_true[4:6, 0, k]
    direction = (x2 - x1) / np.linalg.norm(x2 - x1)
    plt.plot([x2[0], x2[0] - Y[2, 0, k] * direction[0]], [x2[1], x2[1] - Y[2, 0, k] * direction[1]], 'k--', linewidth=0.5)
plt.xlim(-10, 6)
plt.ylim(0, 16)
plt.grid(which="major", color="#DDDDDD", linewidth=0.8, zorder=1)
plt.grid(which="minor", color="#DDDDDD", linestyle="dashed", linewidth=0.5, zorder=2)
plt.tick_params(axis='both', which='both', direction='in')
plt.minorticks_on()
plt.grid(True, which="both")
plt.gca().set_aspect("equal")
plt.legend()
plt.show()

# %%
def r_function(X_0, Y):
    r = np.zeros(((n_y_1 + n_y_2) * K, 1))
    x_1_0 = X_0[:n_x, :]
    x_2_0 = X_0[n_x:, :]
    for k in range(K):
        x_1_k = f_1(k, x_1_0)
        x_2_k = f_2(k, x_2_0)
        y_1_k = Y[:n_y_1, :, k]
        y_2_k = Y[n_y_1:n_y_1 + n_y_2, :, k]
        r[(n_y_1 + n_y_2) * k:(n_y_1 + n_y_2) * k + n_y_1, :] = fractional_matrix_power(R_1, -1/2) @ (P @ x_1_k - y_1_k)
        r[(n_y_1 + n_y_2) * k + n_y_1:(n_y_1 + n_y_2) * (k + 1), :] = sigma_2**(-1) * (np.linalg.norm(P @ x_2_k - P @ x_1_k) - y_2_k)
    return r

def J_jacobian(X_0):
    J = np.zeros(((n_y_1 + n_y_2) * K, n_x + n_x))
    x_1_0 = X_0[:n_x, :]
    x_2_0 = X_0[n_x:, :]
    for k in range(K):
        x_1_k = f_1(k, x_1_0)
        x_2_k = f_2(k, x_2_0)
        J[(n_y_1 + n_y_2) * k:(n_y_1 + n_y_2) * k + n_y_1, :n_x] = fractional_matrix_power(R_1, -1/2) @ P @ np.linalg.matrix_power(A_1, k)
        J[(n_y_1 + n_y_2) * k + n_y_1:(n_y_1 + n_y_2) * (k + 1), :n_x] = -sigma_2**(-1) * ((P @ x_2_k - P @ x_1_k) / np.linalg.norm(P @ x_2_k - P @ x_1_k)).T @ P @ np.linalg.matrix_power(A_1, k)
        J[(n_y_1 + n_y_2) * k + n_y_1:(n_y_1 + n_y_2) * (k + 1), n_x:] = sigma_2**(-1) * ((P @ x_2_k - P @ x_1_k) / np.linalg.norm(P @ x_2_k - P @ x_1_k)).T @ P @ np.linalg.matrix_power(A_2, k)
    return J

def cost_function(X_0, Y):
    r = r_function(X_0, Y)
    return 1 / 2 * np.linalg.norm(r)**2

# %%
def line_search(x_bold_i, delta_x, Y, alpha=0.1, beta=0.7, max_iter=50):
    t = 1
    cost_bold_i = cost_function(x_bold_i, Y)
    for _ in range(max_iter):
        x_pred_i = x_bold_i - t * delta_x
        cost_pred_i = cost_function(x_pred_i, Y)
        if cost_pred_i <= cost_bold_i - alpha * t * (delta_x.T @ delta_x):
            return t
        t *= beta
    return t

# %%
# Solution
x_0 = np.array([[1], [0], [0], [0], [0], [1], [0], [0]])
lambda_0 = 1.0

X_0_i = x_0
lambda_i = lambda_0
i = 0
epsilon = 1e-6
max_iter = 100

grad_i_norms = []
costs = []
lambdas_i = []

while i < max_iter:
    r = r_function(X_0_i, Y)
    J = J_jacobian(X_0_i)
    
    # For plotting the results
    grad_i_norm = np.linalg.norm(J.T @ r)
    grad_i_norms.append(grad_i_norm)
    costs.append(cost_function(X_0_i, Y))
    lambdas_i.append(lambda_i)

    if grad_i_norm < epsilon:
        print(f"STOOOOP\nIteration {i}\nGrad_i_norm = {grad_i_norm}\nx_pred_i cost = {cost_function(X_0_pred_i, Y)} | x_bold_i cost = {cost_function(X_0_i, Y)}\nlambda_i = {lambda_i}\n")
        break

    # Solve for the update step
    delta_X_0_i = np.linalg.inv(J.T @ J + lambda_i * np.eye(J.shape[1])) @ J.T @ r

    X_0_pred_i = X_0_i - delta_X_0_i
    
    print(f"Iteration {i}\nGrad_i_norm = {grad_i_norm}\nx_pred_i cost = {cost_function(X_0_pred_i, Y)} | x_bold_i cost = {cost_function(X_0_i, Y)}\nlambda_i = {lambda_i}\n")
    
    if cost_function(X_0_pred_i, Y) < cost_function(X_0_i, Y):
        X_0_i = X_0_pred_i
        lambda_i *= 0.7
    else:
        lambda_i *= 2.0
        
    # alpha = line_search(X_0_i, delta_X_0_i, Y)
    
    # X_0_pred_i = X_0_i - alpha * delta_X_0_i

    i += 1
    
print("Converged to:", X_0_i)
print("Number of iterations:", i)
print("Final cost:", costs[-1])
print("Final grad norm:", grad_i_norms[-1])
# Out:
# Iteration 0
# Grad_i_norm = 3162967.4133804934
# x_pred_i cost = 18430.291465669194 | x_bold_i cost = 7886206.665670609
# lambda_i = 1.0
#
# Iteration 1
# Grad_i_norm = 14011.891323182921
# x_pred_i cost = 5656.839553627182 | x_bold_i cost = 18430.291465669194
# lambda_i = 0.7
#
# Iteration 2
# Grad_i_norm = 4762.908594062147
# x_pred_i cost = 1734.4600061049018 | x_bold_i cost = 5656.839553627182
# lambda_i = 0.48999999999999994
#
# Iteration 3
# Grad_i_norm = 2195.732297400025
# x_pred_i cost = 325.2108803433676 | x_bold_i cost = 1734.4600061049018
# lambda_i = 0.3429999999999999
#
# Iteration 4
# Grad_i_norm = 513.6239606314116
# x_pred_i cost = 90.43820734162959 | x_bold_i cost = 325.2108803433676
# lambda_i = 0.24009999999999992
#
# Iteration 5
# Grad_i_norm = 82.66088939159086
# x_pred_i cost = 99.1596663198991 | x_bold_i cost = 90.43820734162959
# lambda_i = 0.16806999999999994
#
# Iteration 6
# Grad_i_norm = 82.66088939159086
# x_pred_i cost = 98.79851309225499 | x_bold_i cost = 90.43820734162959
# lambda_i = 0.3361399999999999
#
# Iteration 7
# Grad_i_norm = 82.66088939159086
# x_pred_i cost = 98.11670143702716 | x_bold_i cost = 90.43820734162959
# lambda_i = 0.6722799999999998
#
# Iteration 8
# Grad_i_norm = 82.66088939159086
# x_pred_i cost = 96.8979462618734 | x_bold_i cost = 90.43820734162959
# lambda_i = 1.3445599999999995
#
# Iteration 9
# Grad_i_norm = 82.66088939159086
# x_pred_i cost = 94.92872516133106 | x_bold_i cost = 90.43820734162959
# lambda_i = 2.689119999999999
#
# Iteration 10
# Grad_i_norm = 82.66088939159086
# x_pred_i cost = 92.25743760232217 | x_bold_i cost = 90.43820734162959
# lambda_i = 5.378239999999998
#
# Iteration 11
# Grad_i_norm = 82.66088939159086
# x_pred_i cost = 89.49877798708731 | x_bold_i cost = 90.43820734162959
# lambda_i = 10.756479999999996
#
# Iteration 12
# Grad_i_norm = 138.2437113070687
# x_pred_i cost = 82.78399802640199 | x_bold_i cost = 89.49877798708731
# lambda_i = 7.529535999999997
#
# Iteration 13
# Grad_i_norm = 56.621848678303515
# x_pred_i cost = 91.49184450544215 | x_bold_i cost = 82.78399802640199
# lambda_i = 5.270675199999998
#
# Iteration 14
# Grad_i_norm = 56.621848678303515
# x_pred_i cost = 90.85314636103577 | x_bold_i cost = 82.78399802640199
# lambda_i = 10.541350399999995
#
# Iteration 15
# Grad_i_norm = 56.621848678303515
# x_pred_i cost = 89.97861236041729 | x_bold_i cost = 82.78399802640199
# lambda_i = 21.08270079999999
#
# Iteration 16
# Grad_i_norm = 56.621848678303515
# x_pred_i cost = 88.69310724771347 | x_bold_i cost = 82.78399802640199
# lambda_i = 42.16540159999998
#
# Iteration 17
# Grad_i_norm = 56.621848678303515
# x_pred_i cost = 86.95998674209234 | x_bold_i cost = 82.78399802640199
# lambda_i = 84.33080319999996
#
# Iteration 18
# Grad_i_norm = 56.621848678303515
# x_pred_i cost = 85.04117402575618 | x_bold_i cost = 82.78399802640199
# lambda_i = 168.66160639999993
#
# Iteration 19
# Grad_i_norm = 56.621848678303515
# x_pred_i cost = 83.35380639917652 | x_bold_i cost = 82.78399802640199
# lambda_i = 337.32321279999985
#
# Iteration 20
# Grad_i_norm = 56.621848678303515
# x_pred_i cost = 82.19995775543872 | x_bold_i cost = 82.78399802640199
# lambda_i = 674.6464255999997
#
# Iteration 21
# Grad_i_norm = 73.52055425873803
# x_pred_i cost = 83.33821489446652 | x_bold_i cost = 82.19995775543872
# lambda_i = 472.25249791999977
#
# Iteration 22
# Grad_i_norm = 73.52055425873803
# x_pred_i cost = 82.36090951072892 | x_bold_i cost = 82.19995775543872
# lambda_i = 944.5049958399995
#
# Iteration 23
# Grad_i_norm = 73.52055425873803
# x_pred_i cost = 81.96037467863637 | x_bold_i cost = 82.19995775543872
# lambda_i = 1889.009991679999
#
# Iteration 24
# Grad_i_norm = 49.29996421734299
# x_pred_i cost = 81.99282826452267 | x_bold_i cost = 81.96037467863637
# lambda_i = 1322.3069941759993
#
# Iteration 25
# Grad_i_norm = 49.29996421734299
# x_pred_i cost = 81.92655176253203 | x_bold_i cost = 81.96037467863637
# lambda_i = 2644.6139883519986
#
# Iteration 26
# Grad_i_norm = 18.53524038310956
# x_pred_i cost = 81.92433906222892 | x_bold_i cost = 81.92655176253203
# lambda_i = 1851.229791846399
#
# Iteration 27
# Grad_i_norm = 9.037318788970785
# x_pred_i cost = 81.9265789963485 | x_bold_i cost = 81.92433906222892
# lambda_i = 1295.8608542924792
#
# Iteration 28
# Grad_i_norm = 9.037318788970785
# x_pred_i cost = 81.92104254474734 | x_bold_i cost = 81.92433906222892
# lambda_i = 2591.7217085849584
#
# Iteration 29
# Grad_i_norm = 6.284180856246538
# x_pred_i cost = 81.91905915853408 | x_bold_i cost = 81.92104254474734
# lambda_i = 1814.2051960094707
#
# Iteration 30
# Grad_i_norm = 4.466644655972996
# x_pred_i cost = 81.91751258384974 | x_bold_i cost = 81.91905915853408
# lambda_i = 1269.9436372066293
#
# Iteration 31
# Grad_i_norm = 6.900449169623547
# x_pred_i cost = 81.92906827889699 | x_bold_i cost = 81.91751258384974
# lambda_i = 888.9605460446405
#
# Iteration 32
# Grad_i_norm = 6.900449169623547
# x_pred_i cost = 81.91601634077496 | x_bold_i cost = 81.91751258384974
# lambda_i = 1777.921092089281
#
# Iteration 33
# Grad_i_norm = 8.880072804220573
# x_pred_i cost = 81.91957397559123 | x_bold_i cost = 81.91601634077496
# lambda_i = 1244.5447644624967
#
# Iteration 34
# Grad_i_norm = 8.880072804220573
# x_pred_i cost = 81.91292722789264 | x_bold_i cost = 81.91601634077496
# lambda_i = 2489.0895289249934
#
# Iteration 35
# Grad_i_norm = 6.637803927117805
# x_pred_i cost = 81.91114840416266 | x_bold_i cost = 81.91292722789264
# lambda_i = 1742.3626702474953
#
# Iteration 36
# Grad_i_norm = 5.276322593722526
# x_pred_i cost = 81.9107482878655 | x_bold_i cost = 81.91114840416266
# lambda_i = 1219.6538691732467
#
# Iteration 37
# Grad_i_norm = 8.95192874550134
# x_pred_i cost = 81.9372522546241 | x_bold_i cost = 81.9107482878655
# lambda_i = 853.7577084212726
#
# Iteration 38
# Grad_i_norm = 8.95192874550134
# x_pred_i cost = 81.91030589749155 | x_bold_i cost = 81.9107482878655
# lambda_i = 1707.5154168425452
#
# Iteration 39
# Grad_i_norm = 12.281292127129166
# x_pred_i cost = 81.9223334212819 | x_bold_i cost = 81.91030589749155
# lambda_i = 1195.2607917897815
#
# Iteration 40
# Grad_i_norm = 12.281292127129166
# x_pred_i cost = 81.90561887328073 | x_bold_i cost = 81.91030589749155
# lambda_i = 2390.521583579563
#
# Iteration 41
# Grad_i_norm = 9.678396606230255
# x_pred_i cost = 81.90446217761625 | x_bold_i cost = 81.90561887328073
# lambda_i = 1673.365108505694
#
# Iteration 42
# Grad_i_norm = 8.394371610052511
# x_pred_i cost = 81.90955504899695 | x_bold_i cost = 81.90446217761625
# lambda_i = 1171.3555759539856
#
# Iteration 43
# Grad_i_norm = 8.394371610052511
# x_pred_i cost = 81.90166698122285 | x_bold_i cost = 81.90446217761625
# lambda_i = 2342.7111519079713
#
# Iteration 44
# Grad_i_norm = 7.030812444566635
# x_pred_i cost = 81.90024151339483 | x_bold_i cost = 81.90166698122285
# lambda_i = 1639.8978063355798
#
# Iteration 45
# Grad_i_norm = 6.542943205575212
# x_pred_i cost = 81.90267718156818 | x_bold_i cost = 81.90024151339483
# lambda_i = 1147.928464434906
#
# Iteration 46
# Grad_i_norm = 6.542943205575212
# x_pred_i cost = 81.89807207926124 | x_bold_i cost = 81.90024151339483
# lambda_i = 2295.856928869812
#
# Iteration 47
# Grad_i_norm = 5.7398240218329075
# x_pred_i cost = 81.8965416743901 | x_bold_i cost = 81.89807207926124
# lambda_i = 1607.0998502088682
#
# Iteration 48
# Grad_i_norm = 5.642922426653264
# x_pred_i cost = 81.89795377969979 | x_bold_i cost = 81.8965416743901
# lambda_i = 1124.9698951462076
#
# Iteration 49
# Grad_i_norm = 5.642922426653264
# x_pred_i cost = 81.89462116157712 | x_bold_i cost = 81.8965416743901
# lambda_i = 2249.939790292415
#
# Iteration 50
# Grad_i_norm = 5.147790156736909
# x_pred_i cost = 81.89307360693579 | x_bold_i cost = 81.89462116157712
# lambda_i = 1574.9578532046905
#
# Iteration 51
# Grad_i_norm = 5.307075433757835
# x_pred_i cost = 81.89432590665334 | x_bold_i cost = 81.89307360693579
# lambda_i = 1102.4704972432833
#
# Iteration 52
# Grad_i_norm = 5.307075433757835
# x_pred_i cost = 81.89125213756203 | x_bold_i cost = 81.89307360693579
# lambda_i = 2204.9409944865665
#
# Iteration 53
# Grad_i_norm = 5.00960466441638
# x_pred_i cost = 81.88976208861257 | x_bold_i cost = 81.89125213756203
# lambda_i = 1543.4586961405964
#
# Iteration 54
# Grad_i_norm = 5.400580421182003
# x_pred_i cost = 81.89158009877781 | x_bold_i cost = 81.88976208861257
# lambda_i = 1080.4210872984174
#
# Iteration 55
# Grad_i_norm = 5.400580421182003
# x_pred_i cost = 81.88795970190368 | x_bold_i cost = 81.88976208861257
# lambda_i = 2160.842174596835
#
# Iteration 56
# Grad_i_norm = 5.260417868118059
# x_pred_i cost = 81.88663013025973 | x_bold_i cost = 81.88795970190368
# lambda_i = 1512.5895222177844
#
# Iteration 57
# Grad_i_norm = 5.9308412888969935
# x_pred_i cost = 81.8900110937221 | x_bold_i cost = 81.88663013025973
# lambda_i = 1058.812665552449
#
# Iteration 58
# Grad_i_norm = 5.9308412888969935
# x_pred_i cost = 81.88478221312593 | x_bold_i cost = 81.88663013025973
# lambda_i = 2117.625331104898
#
# Iteration 59
# Grad_i_norm = 5.955325488384197
# x_pred_i cost = 81.88380727948964 | x_bold_i cost = 81.88478221312593
# lambda_i = 1482.3377317734287
#
# Iteration 60
# Grad_i_norm = 7.027302988622777
# x_pred_i cost = 81.89062000641572 | x_bold_i cost = 81.88380727948964
# lambda_i = 1037.6364122414
#
# Iteration 61
# Grad_i_norm = 7.027302988622777
# x_pred_i cost = 81.88183026736965 | x_bold_i cost = 81.88380727948964
# lambda_i = 2075.2728244828
#
# Iteration 62
# Grad_i_norm = 7.270027328480552
# x_pred_i cost = 81.88163874486405 | x_bold_i cost = 81.88183026736965
# lambda_i = 1452.6909771379599
#
# Iteration 63
# Grad_i_norm = 8.965480020358827
# x_pred_i cost = 81.89590181433303 | x_bold_i cost = 81.88163874486405
# lambda_i = 1016.8836839965718
#
# Iteration 64
# Grad_i_norm = 8.965480020358827
# x_pred_i cost = 81.87937741263707 | x_bold_i cost = 81.88163874486405
# lambda_i = 2033.7673679931436
#
# Iteration 65
# Grad_i_norm = 9.533942275994214
# x_pred_i cost = 81.88099061373254 | x_bold_i cost = 81.87937741263707
# lambda_i = 1423.6371575952005
#
# Iteration 66
# Grad_i_norm = 9.533942275994214
# x_pred_i cost = 81.87663116187483 | x_bold_i cost = 81.87937741263707
# lambda_i = 2847.274315190401
#
# Iteration 67
# Grad_i_norm = 5.727320433411487
# x_pred_i cost = 81.87517775580238 | x_bold_i cost = 81.87663116187483
# lambda_i = 1993.0920206332805
#
# Iteration 68
# Grad_i_norm = 3.4059702295324605
# x_pred_i cost = 81.87361692931943 | x_bold_i cost = 81.87517775580238
# lambda_i = 1395.1644144432962
#
# Iteration 69
# Grad_i_norm = 4.4098968439851225
# x_pred_i cost = 81.87534248364486 | x_bold_i cost = 81.87361692931943
# lambda_i = 976.6150901103073
#
# Iteration 70
# Grad_i_norm = 4.4098968439851225
# x_pred_i cost = 81.87213998432037 | x_bold_i cost = 81.87361692931943
# lambda_i = 1953.2301802206146
#
# Iteration 71
# Grad_i_norm = 5.017750782573451
# x_pred_i cost = 81.87137631550809 | x_bold_i cost = 81.87213998432037
# lambda_i = 1367.26112615443
#
# Iteration 72
# Grad_i_norm = 6.950716259332302
# x_pred_i cost = 81.88162885973537 | x_bold_i cost = 81.87137631550809
# lambda_i = 957.0827883081009
#
# Iteration 73
# Grad_i_norm = 6.950716259332302
# x_pred_i cost = 81.86985841156697 | x_bold_i cost = 81.87137631550809
# lambda_i = 1914.1655766162019
#
# Iteration 74
# Grad_i_norm = 8.195552724202278
# x_pred_i cost = 81.87180296121089 | x_bold_i cost = 81.86985841156697
# lambda_i = 1339.9159036313413
#
# Iteration 75
# Grad_i_norm = 8.195552724202278
# x_pred_i cost = 81.86753642099531 | x_bold_i cost = 81.86985841156697
# lambda_i = 2679.8318072626826
#
# Iteration 76
# Grad_i_norm = 5.586446688004025
# x_pred_i cost = 81.86614485188055 | x_bold_i cost = 81.86753642099531
# lambda_i = 1875.8822650838777
#
# Iteration 77
# Grad_i_norm = 3.940658028187109
# x_pred_i cost = 81.86505673137253 | x_bold_i cost = 81.86614485188055
# lambda_i = 1313.1175855587144
#
# Iteration 78
# Grad_i_norm = 5.8053343086960005
# x_pred_i cost = 81.872736042642 | x_bold_i cost = 81.86505673137253
# lambda_i = 919.1823098911
#
# Iteration 79
# Grad_i_norm = 5.8053343086960005
# x_pred_i cost = 81.86379496096907 | x_bold_i cost = 81.86505673137253
# lambda_i = 1838.3646197822
#
# Iteration 80
# Grad_i_norm = 7.289539964462566
# x_pred_i cost = 81.86571639485246 | x_bold_i cost = 81.86379496096907
# lambda_i = 1286.85523384754
#
# Iteration 81
# Grad_i_norm = 7.289539964462566
# x_pred_i cost = 81.86176512105975 | x_bold_i cost = 81.86379496096907
# lambda_i = 2573.71046769508
#
# Iteration 82
# Grad_i_norm = 5.379224526890723
# x_pred_i cost = 81.86043612957965 | x_bold_i cost = 81.86176512105975
# lambda_i = 1801.5973273865557
#
# Iteration 83
# Grad_i_norm = 4.23132196953131
# x_pred_i cost = 81.8597866893384 | x_bold_i cost = 81.86043612957965
# lambda_i = 1261.1181291705889
#
# Iteration 84
# Grad_i_norm = 6.754470413109819
# x_pred_i cost = 81.8736336522308 | x_bold_i cost = 81.8597866893384
# lambda_i = 882.7826904194121
#
# Iteration 85
# Grad_i_norm = 6.754470413109819
# x_pred_i cost = 81.85889742313849 | x_bold_i cost = 81.8597866893384
# lambda_i = 1765.5653808388242
#
# Iteration 86
# Grad_i_norm = 9.040210928499135
# x_pred_i cost = 81.864437014199 | x_bold_i cost = 81.85889742313849
# lambda_i = 1235.895766587177
#
# Iteration 87
# Grad_i_norm = 9.040210928499135
# x_pred_i cost = 81.85634432066381 | x_bold_i cost = 81.85889742313849
# lambda_i = 2471.791533174354
#
# Iteration 88
# Grad_i_norm = 7.1217074918387295
# x_pred_i cost = 81.85524574141729 | x_bold_i cost = 81.85634432066381
# lambda_i = 1730.2540732220475
#
# Iteration 89
# Grad_i_norm = 6.143177332841658
# x_pred_i cost = 81.85703908069996 | x_bold_i cost = 81.85524574141729
# lambda_i = 1211.177851255433
#
# Iteration 90
# Grad_i_norm = 6.143177332841658
# x_pred_i cost = 81.85356475516079 | x_bold_i cost = 81.85524574141729
# lambda_i = 2422.355702510866
#
# Iteration 91
# Grad_i_norm = 5.076670356574884
# x_pred_i cost = 81.85235556155709 | x_bold_i cost = 81.85356475516079
# lambda_i = 1695.6489917576062
#
# Iteration 92
# Grad_i_norm = 4.648954449078586
# x_pred_i cost = 81.85263992721882 | x_bold_i cost = 81.85235556155709
# lambda_i = 1186.9542942303242
#
# Iteration 93
# Grad_i_norm = 4.648954449078586
# x_pred_i cost = 81.85099345522784 | x_bold_i cost = 81.85235556155709
# lambda_i = 2373.9085884606484
#
# Iteration 94
# Grad_i_norm = 4.007082213777115
# x_pred_i cost = 81.84972930300763 | x_bold_i cost = 81.85099345522784
# lambda_i = 1661.7360119224538
#
# Iteration 95
# Grad_i_norm = 3.863944326135812
# x_pred_i cost = 81.84936915585743 | x_bold_i cost = 81.84972930300763
# lambda_i = 1163.2152083457177
#
# Iteration 96
# Grad_i_norm = 7.027455549231853
# x_pred_i cost = 81.87042990066647 | x_bold_i cost = 81.84936915585743
# lambda_i = 814.2506458420023
#
# Iteration 97
# Grad_i_norm = 7.027455549231853
# x_pred_i cost = 81.84945232319232 | x_bold_i cost = 81.84936915585743
# lambda_i = 1628.5012916840046
#
# Iteration 98
# Grad_i_norm = 7.027455549231853
# x_pred_i cost = 81.84668501580825 | x_bold_i cost = 81.84936915585743
# lambda_i = 3257.0025833680093
#
# Iteration 99
# Grad_i_norm = 4.823159755768128
# x_pred_i cost = 81.84564114838267 | x_bold_i cost = 81.84668501580825
# lambda_i = 2279.901808357606
#
# Converged to: [[  1.00174883]
#  [  0.99628075]
#  [-15.00080478]
#  [  3.00452528]
#  [ -1.9887629 ]
#  [  1.33791795]
#  [ -2.95622866]
#  [  2.66080136]]
# Number of iterations: 100
# Final cost: 81.84668501580825
# Final grad norm: 4.823159755768128

# %%
x_1_est = np.zeros((n_x, 1, K))
x_2_est = np.zeros((n_x, 1, K))
for k in range(K):
    x_1_est[:, :, k] = f_1(k, X_0_i[:n_x, :])
    x_2_est[:, :, k] = f_2(k, X_0_i[n_x:, :])

# %%
plt.plot(X_true[0, 0, :], X_true[1, 0, :], '.-', label='Agent 1 true')
plt.plot(X_true[4, 0, :], X_true[5, 0, :], '.-', label='Agent 2 true')
plt.plot(x_1_est[0, 0, :], x_1_est[1, 0, :], '.-', label='Agent 1 est')
plt.plot(x_2_est[0, 0, :], x_2_est[1, 0, :], '.-', label='Agent 2 est')
plt.xlim(-10, 6)
plt.ylim(0, 16)
plt.grid(which="major", color="#DDDDDD", linewidth=0.8, zorder=1)
plt.grid(which="minor", color="#DDDDDD", linestyle="dashed", linewidth=0.5, zorder=2)
plt.tick_params(axis='both', which='both', direction='in')
plt.minorticks_on()
plt.grid(True, which="both")
plt.gca().set_aspect("equal")
plt.legend()
plt.show()
